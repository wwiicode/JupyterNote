# %%
import pandas as pd

# %%
df = pd.read_csv('tutorial.csv',sep = ",")
df
# Out:
#        col0      col1      col2      col3
# 0 -0.722876 -1.330682  1.309208  0.232378
# 1  1.160396 -0.730879  0.677368  1.044722
# 2 -1.062870 -0.503704 -0.238536 -1.417937
# 3  0.437078  0.362640 -0.111228 -1.649853

# %%
df.describe()
# Out:
#            col0      col1      col2      col3
# count  4.000000  4.000000  4.000000  4.000000
# mean  -0.047068 -0.550656  0.409203 -0.447672
# std    1.029715  0.701720  0.723956  1.300815
# min   -1.062870 -1.330682 -0.238536 -1.649853
# 25%   -0.807875 -0.880830 -0.143055 -1.475916
# 50%   -0.142899 -0.617291  0.283070 -0.592780
# 75%    0.617907 -0.287118  0.835328  0.435464
# max    1.160396  0.362640  1.309208  1.044722

# %%
df
# Out:
#        col0      col1      col2      col3
# 0 -0.722876 -1.330682  1.309208  0.232378
# 1  1.160396 -0.730879  0.677368  1.044722
# 2 -1.062870 -0.503704 -0.238536 -1.417937
# 3  0.437078  0.362640 -0.111228 -1.649853

# %%
df.loc[2:4, 'col3']
# Out:
# 2   -1.417937
# 3   -1.649853
# Name: col3, dtype: float64

# %%
df2 = pd.read_csv('servo.csv', sep=',', header = None, names = ["motor", "screw", "pgain", "vgain", "class"])
df2
# Out:
#     motor screw  pgain  vgain     class
# 0       E     E      5      4  0.281251
# 1       B     D      6      5  0.506252
# 2       D     D      4      3  0.356251
# 3       B     A      3      2  5.500033
# 4       D     B      6      5  0.356251
# 5       E     C      4      3  0.806255
# 6       C     A      3      2  5.100014
# 7       A     A      3      2  5.700042
# 8       C     A      6      5  0.768754
# 9       D     A      4      1  1.031254
# 10      B     E      6      5  0.468752
# 11      E     C      5      4  0.393752
# 12      B     C      4      1  0.281251
# 13      E     C      3      1  1.100000
# 14      C     C      5      4  0.506252
# 15      E     B      3      2  1.899990
# 16      D     C      3      1  0.900001
# 17      B     C      5      4  0.468752
# 18      B     B      5      4  0.543753
# 19      C     E      4      2  0.206250
# 20      E     D      4      3  0.918755
# 21      A     D      4      3  1.106248
# ...

# %%
len((df2[df2.vgain == 5]))
# Out:
# 22

# %%
len(df2[(df2.motor == 'E') & (df2.screw == 'E')])
# Out:
# 6

# %%
df2[df2.pgain == 4].mean()
# Out:
# pgain    4.000000
# vgain    2.060606
# class    0.673298
# dtype: float64

# %%
df3 = pd.read_html('http://www.espn.com/nhl/statistics/player/_/stat/points/sort/points/year/2015/seasontype/2',header=1)[0]
df3
# Out:
#      RK                  PLAYER  TEAM   GP    G    A  PTS  +/-  PIM  PTS/G  \
# 0     1          Jamie Benn, LW   DAL   82   35   52   87    1   64   1.06
# 1     2         John Tavares, C   NYI   82   38   48   86    5   46   1.05
# 2     3        Sidney Crosby, C   PIT   77   28   56   84    5   47   1.09
# 3     4       Alex Ovechkin, LW   WSH   81   53   28   81   10   58   1.00
# 4   NaN       Jakub Voracek, RW   PHI   82   22   59   81    1   78   0.99
# 5     6    Nicklas Backstrom, C   WSH   82   18   60   78    5   40   0.95
# 6     7         Tyler Seguin, C   DAL   71   37   40   77   -1   20   1.08
# 7     8         Jiri Hudler, LW   CGY   78   31   45   76   17   14   0.97
# 8   NaN        Daniel Sedin, LW   VAN   82   20   56   76    5   18   0.93
# 9    10  Vladimir Tarasenko, RW   STL   77   37   36   73   27   31   0.95
# 10  NaN                      PP    SH  NaN  NaN  NaN  NaN  NaN  NaN    NaN
# ...

# %%
len(df3)
# Out:
# 43

# %%
df3.drop(df3.columns[[0]], axis = 1, inplace = True)
df3
# Out:
# /Users/zhihuanwilson/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#                     PLAYER  TEAM  GP   G   A  PTS  +/-  PIM  PTS/G  SOG   PCT  \
# 0           Jamie Benn, LW   DAL  82  35  52   87    1   64   1.06  253  13.8
# 1          John Tavares, C   NYI  82  38  48   86    5   46   1.05  278  13.7
# 2         Sidney Crosby, C   PIT  77  28  56   84    5   47   1.09  237  11.8
# 3        Alex Ovechkin, LW   WSH  81  53  28   81   10   58   1.00  395  13.4
# 4        Jakub Voracek, RW   PHI  82  22  59   81    1   78   0.99  221  10.0
# 5     Nicklas Backstrom, C   WSH  82  18  60   78    5   40   0.95  153  11.8
# 6          Tyler Seguin, C   DAL  71  37  40   77   -1   20   1.08  280  13.2
# ...

# %%
df3 = df3.dropna(axis = 0, thresh = 4)
df3
# Out:
#      RK                  PLAYER  TEAM  GP   G   A  PTS  +/-  PIM  PTS/G  SOG  \
# 0     1          Jamie Benn, LW   DAL  82  35  52   87    1   64   1.06  253
# 1     2         John Tavares, C   NYI  82  38  48   86    5   46   1.05  278
# 2     3        Sidney Crosby, C   PIT  77  28  56   84    5   47   1.09  237
# 3     4       Alex Ovechkin, LW   WSH  81  53  28   81   10   58   1.00  395
# 4   NaN       Jakub Voracek, RW   PHI  82  22  59   81    1   78   0.99  221
# 5     6    Nicklas Backstrom, C   WSH  82  18  60   78    5   40   0.95  153
# 6     7         Tyler Seguin, C   DAL  71  37  40   77   -1   20   1.08  280
# 7     8         Jiri Hudler, LW   CGY  78  31  45   76   17   14   0.97  158
# 8   NaN        Daniel Sedin, LW   VAN  82  20  56   76    5   18   0.93  226
# 9    10  Vladimir Tarasenko, RW   STL  77  37  36   73   27   31   0.95  264
# 11   RK                  PLAYER  TEAM  GP   G   A  PTS  +/-  PIM  PTS/G  SOG
# ...

# %%
len(df3)
# Out:
# 43

# %%
df3.drop([11,23, 35], inplace = True)
# Out:
# /Users/zhihuanwilson/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
len(df3)
# Out:
# 40

# %%
df3
# Out:
#                     PLAYER TEAM  GP   G   A PTS  +/- PIM PTS/G  SOG   PCT GWG  \
# 0           Jamie Benn, LW  DAL  82  35  52  87    1  64  1.06  253  13.8   6
# 1          John Tavares, C  NYI  82  38  48  86    5  46  1.05  278  13.7   8
# 2         Sidney Crosby, C  PIT  77  28  56  84    5  47  1.09  237  11.8   3
# 3        Alex Ovechkin, LW  WSH  81  53  28  81   10  58  1.00  395  13.4  11
# 4        Jakub Voracek, RW  PHI  82  22  59  81    1  78  0.99  221  10.0   3
# 5     Nicklas Backstrom, C  WSH  82  18  60  78    5  40  0.95  153  11.8   3
# 6          Tyler Seguin, C  DAL  71  37  40  77   -1  20  1.08  280  13.2   5
# 7          Jiri Hudler, LW  CGY  78  31  45  76   17  14  0.97  158  19.6   5
# 8         Daniel Sedin, LW  VAN  82  20  56  76    5  18  0.93  226   8.9   5
# 9   Vladimir Tarasenko, RW  STL  77  37  36  73   27  31  0.95  264  14.0   6
# 12        Nick Foligno, LW  CBJ  79  31  42  73   16  50  0.92  182  17.0   3
# ...

# %%
df3.dtypes
# Out:
# PLAYER    object
# TEAM      object
# GP         int64
# G         object
# A         object
# PTS       object
# +/-       object
# PIM       object
# PTS/G     object
# SOG       object
# PCT       object
# GWG       object
# G.1       object
# A.1       object
# G.2       object
# A.2       object
# dtype: object

# %%
len(df3.PCT.unique())
# Out:
# dtype('O')

# %%
df3
# Out:
#                     PLAYER TEAM  GP   G   A PTS  +/- PIM PTS/G  SOG   PCT GWG  \
# 0           Jamie Benn, LW  DAL  82  35  52  87    1  64  1.06  253  13.8   6
# 1          John Tavares, C  NYI  82  38  48  86    5  46  1.05  278  13.7   8
# 2         Sidney Crosby, C  PIT  77  28  56  84    5  47  1.09  237  11.8   3
# 3        Alex Ovechkin, LW  WSH  81  53  28  81   10  58  1.00  395  13.4  11
# 4        Jakub Voracek, RW  PHI  82  22  59  81    1  78  0.99  221  10.0   3
# 5     Nicklas Backstrom, C  WSH  82  18  60  78    5  40  0.95  153  11.8   3
# 6          Tyler Seguin, C  DAL  71  37  40  77   -1  20  1.08  280  13.2   5
# 7          Jiri Hudler, LW  CGY  78  31  45  76   17  14  0.97  158  19.6   5
# 8         Daniel Sedin, LW  VAN  82  20  56  76    5  18  0.93  226   8.9   5
# 9   Vladimir Tarasenko, RW  STL  77  37  36  73   27  31  0.95  264  14.0   6
# 12        Nick Foligno, LW  CBJ  79  31  42  73   16  50  0.92  182  17.0   3
# ...

# %%
df3.GP = pd.to_numeric(df3.GP, errors='coerce')

# %%
df3.loc[15:16, 'GP'].sum()
# Out:
# u'8277'

# %%
df4 = pd.read_html('https://raw.githubusercontent.com/authman/DAT210x/master/Module2/Datasets/census.data', header=1)[0]
df4

# %%
df4 = pd.read_csv('census.csv', header = None, names = ['education', 'age', 'capital-gain', 'race', 'capital-loss', 'hours-per-week', 'sex', 'classification'])
df4
# Out:
#           education  age capital-gain                race  capital-loss  \
# 0         Bachelors   39         2174               White             0
# 1         Bachelors   50            ?               White             0
# 2           HS-grad   38            ?               White             0
# 3              11th   53            ?               Black             0
# 4         Bachelors   28            0               Black             0
# 5           Masters   37            0               White             0
# 6               9th   49            0               Black             0
# 7           HS-grad   52            0               White             0
# 8           Masters   31        14084               White             0
# 9         Bachelors   42         5178               White             0
# 10     Some-college   37            0               Black             0
# 11        Bachelors   30            0  Asian-Pac-Islander             0
# ...
